# %%
import pandas as pd

# %%
a = pd.read_csv("Twitter_sentiment2.csv")
b = pd.read_csv("Articles_sentiment2.csv")
a = a.dropna(axis=1)


merged = b.merge(a, on='Date')
# df = merged.rename(columns={'Sentiment_x': 'Sentiment_Twitter', 'Sentiment_y': 'Sentiment_Articles'})
df = merged
df = df[df.Number_of_Tweets != 0]

merged.to_csv("Tweets_Articles_sentiment2.csv", index=False)
df
# Out:
#           Date  Neg_A_Sentiment  Neut_A_Sentiment  Number_of_Articles  \
# 10  2017-03-11            0.000               0.0                   0
# 11  2017-03-12            0.000               0.0                   0
# 12  2017-03-13            0.000               0.0                   0
# 13  2017-03-14            0.000               0.0                   0
# 14  2017-03-15            0.000               0.0                   0
# 15  2017-03-16            0.000               0.0                   0
# 16  2017-03-17            0.000               0.0                   0
# 17  2017-03-18            0.000               0.0                   0
# 18  2017-03-19            0.000               0.0                   0
# 19  2017-03-20            0.000               0.0                   0
# 20  2017-03-21            0.000               0.0                   0
# 30  2017-03-31            0.000               0.0                   0
# ...
